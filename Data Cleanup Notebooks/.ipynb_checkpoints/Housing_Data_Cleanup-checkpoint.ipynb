# %%
# import Dependencies and CSV
import os 
import pandas as pd

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
# document name = "Housing_New_York_Units_by_Building"

csv_path = "../ELT_CSVs/Housing_New_York_Units_by_Building.csv"
raw_housing_df = pd.read_csv(csv_path)
raw_housing_df.head()
# Out:
#    Project ID  Project Name Project Start Date Project Completion Date  \
# 0       67358  CONFIDENTIAL         06/29/2018                     NaN
# 1       67359  CONFIDENTIAL         06/29/2018                     NaN
# 2       67362  CONFIDENTIAL         06/29/2018                     NaN
# 3       67365  CONFIDENTIAL         06/29/2018                     NaN
# 4       67373  CONFIDENTIAL         06/29/2018                     NaN
#
#    Building ID Number Street        Borough  Postcode  BBL     ...      \
# 0          NaN   ----   ----         Queens       NaN  NaN     ...
# 1          NaN   ----   ----         Queens       NaN  NaN     ...
# 2          NaN   ----   ----  Staten Island       NaN  NaN     ...
# 3          NaN   ----   ----       Brooklyn       NaN  NaN     ...
# 4          NaN   ----   ----       Brooklyn       NaN  NaN     ...
#
#    2-BR Units 3-BR Units  4-BR Units 5-BR Units 6-BR+ Units  Unknown-BR Units  \
# 0           0          2           0          0           0                 0
# 1           0          2           0          0           0                 0
# 2           1          0           0          0           0                 0
# 3           4          0           0          0           0                 0
# 4           0          0           0          0           0                 2
#
#    Counted Rental Units  Counted Homeownership Units  All Counted Units  \
# 0                     0                            2                  2
# 1                     0                            2                  2
# 2                     0                            1                  1
# 3                     0                            4                  4
# 4                     0                            2                  2
#
#   Total Units
# 0           2
# 1           2
# 2           1
# 3           4
# 4           2
#
# [5 rows x 41 columns]

# %%
# Inspect the column names
raw_housing_df.columns
# Out:
# Index(['Project ID', 'Project Name', 'Project Start Date',
#        'Project Completion Date', 'Building ID', 'Number', 'Street', 'Borough',
#        'Postcode', 'BBL', 'BIN', 'Community Board', 'Council District',
#        'Census Tract', 'NTA - Neighborhood Tabulation Area', 'Latitude',
#        'Longitude', 'Latitude (Internal)', 'Longitude (Internal)',
#        'Building Completion Date', 'Reporting Construction Type',
#        'Extended Affordability Only', 'Prevailing Wage Status',
#        'Extremely Low Income Units', 'Very Low Income Units',
#        'Low Income Units', 'Moderate Income Units', 'Middle Income Units',
#        'Other Income Units', 'Studio Units', '1-BR Units', '2-BR Units',
#        '3-BR Units', '4-BR Units', '5-BR Units', '6-BR+ Units',
#        'Unknown-BR Units', 'Counted Rental Units',
#        'Counted Homeownership Units', 'All Counted Units', 'Total Units'],
#       dtype='object')

# %%
# reduce the selected columns to only information we need
reduced_housing_df = raw_housing_df.loc[:, ["Project Name", "Borough", 
                                "Postcode", "Census Tract", 
                        "Prevailing Wage Status", "Counted Rental Units", 
                                "Counted Homeownership Units", 
                            "All Counted Units", "Total Units"]]

reduced_housing_df.head()
# Out:
#    Project Name        Borough  Postcode Census Tract Prevailing Wage Status  \
# 0  CONFIDENTIAL         Queens       NaN          NaN    Non Prevailing Wage
# 1  CONFIDENTIAL         Queens       NaN          NaN    Non Prevailing Wage
# 2  CONFIDENTIAL  Staten Island       NaN          NaN    Non Prevailing Wage
# 3  CONFIDENTIAL       Brooklyn       NaN          NaN    Non Prevailing Wage
# 4  CONFIDENTIAL       Brooklyn       NaN          NaN    Non Prevailing Wage
#
#    Counted Rental Units  Counted Homeownership Units  All Counted Units  \
# 0                     0                            2                  2
# 1                     0                            2                  2
# 2                     0                            1                  1
# 3                     0                            4                  4
# 4                     0                            2                  2
#
#   Total Units
# 0           2
# 1           2
# 2           1
# 3           4
# 4           2

# %%
# Remove any rows with NaN values 
removed_nan_df = reduced_housing_df.dropna(axis=0, how='any', inplace=False)

removed_nan_df.head()
# Out:
#                          Project Name    Borough  Postcode Census Tract  \
# 14  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029.0        17401
# 15  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029.0        17401
# 16  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029.0        17401
# 17  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029.0        17401
# 18               TRIPLE HDFC.HPO.FY19  Manhattan   10029.0          178
#
#    Prevailing Wage Status  Counted Rental Units  Counted Homeownership Units  \
# 14    Non Prevailing Wage                    59                            0
# 15    Non Prevailing Wage                    59                            0
# 16    Non Prevailing Wage                   164                            0
# 17    Non Prevailing Wage                   164                            0
# 18    Non Prevailing Wage                     8                            0
#
#     All Counted Units Total Units
# 14                 59          59
# 15                 59          59
# 16                164         164
# 17                164         164
# 18                  8           8

# %%
# Clean up the Postcode Column
# Remove the decimal point
removed_nan_df['Postcode'] = removed_nan_df['Postcode'].astype(str).replace('\.0', '', regex=True)

# Rename Postcode to Zipcode
cleaned_housing_df = removed_nan_df.rename(index=str, columns={"Postcode": "Zipcode"})

cleaned_housing_df.head()
# Out:
# C:\Users\Courtney\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                          Project Name    Borough Zipcode Census Tract  \
# 14  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029        17401
# 15  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029        17401
# 16  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029        17401
# 17  LAKEVIEW APARTMENTS HDFC.HPO.FY19  Manhattan   10029        17401
# 18               TRIPLE HDFC.HPO.FY19  Manhattan   10029          178
#
#    Prevailing Wage Status  Counted Rental Units  Counted Homeownership Units  \
# 14    Non Prevailing Wage                    59                            0
# 15    Non Prevailing Wage                    59                            0
# 16    Non Prevailing Wage                   164                            0
# 17    Non Prevailing Wage                   164                            0
# 18    Non Prevailing Wage                     8                            0
#
#     All Counted Units Total Units
# 14                 59          59
# 15                 59          59
# 16                164         164
# 17                164         164
# 18                  8           8

# %%
# Write cleaned dataframe to new CSV File

cleaned_housing_df.to_csv('Cleaned_Housing_Data.csv', encoding='utf-8', index=False)
